# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
report_dir = "../reports/model_greater_manchester/1/"
with open(report_dir + "parameters.json") as f:
    parameters = json.load(f)
report = pd.read_csv(report_dir + "report.csv")
report['day'] = report['time_step'] / parameters['time_steps_per_day']
report = report.set_index('day')
report.drop('day', axis='columns', inplace=True)
fig, ax = plt.subplots()
report.plot(ax=ax)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-102-71ae990faed7> in <module>
#       5 report['day'] = report['time_step'] / parameters['time_steps_per_day']
#       6 report = report.set_index('day')
# ----> 7 report.drop('day', axis='columns', inplace=True)
#       8 fig, ax = plt.subplots()
#       9 report.plot(ax=ax)
#
# /mnt/c/Users/Alfred/CLionProjects/outbreak-sim/python/venv/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4303                 weight  1.0     0.8
#    4304         """
# -> 4305         return super().drop(
#    4306             labels=labels,
#    4307             axis=axis,
#
# /mnt/c/Users/Alfred/CLionProjects/outbreak-sim/python/venv/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
report = pd.read_csv("../reports/model_tower_hamlets/2.csv")
report = report.set_index('time_step')
fig, ax = plt.subplots()
report.plot(ax=ax)
# Out:
# <AxesSubplot:xlabel='time_step'>

# %%
report2 = pd.read_csv("../reports/model_london_se_commuter_ring/1.csv")
report2 = report2.set_index('time_step')
fig, ax = plt.subplots()
report2.plot(ax=ax)
# Out:
# <AxesSubplot:xlabel='time_step'>

# %%
report2 = pd.read_csv("../reports/model_london_se_commuter_ring/2.csv")
report2 = report2.set_index('time_step')
fig, ax = plt.subplots()
report2.plot(ax=ax)
# Out:
# <AxesSubplot:xlabel='time_step'>

# %%
report2 = pd.read_csv("../reports/model_london_se_commuter_ring/3.csv")
report2 = report2.set_index('time_step')
fig, ax = plt.subplots()
report2[['num_presymptomatic', 'num_infected', 'num_recovered']].plot(ax=ax)
# Out:
# <AxesSubplot:xlabel='time_step'>

# %%
report2 = pd.read_csv("../reports/model_london_se_commuter_ring/3.csv")
report2 = report2.set_index('time_step')
fig, ax = plt.subplots()
report2.plot(ax=ax)
# Out:
# <AxesSubplot:xlabel='time_step'>

# %%
report2 = pd.read_csv("../reports/model_london_se_commuter_ring/4.csv")
report2 = report2.set_index('time_step')
fig, ax = plt.subplots()
report2[['num_presymptomatic', 'num_infected', 'num_recovered']].plot(ax=ax)
# Out:
# <AxesSubplot:xlabel='time_step'>

# %%
report2 = pd.read_csv("../reports/model_london_se_commuter_ring/5.csv")
report2 = report2.set_index('time_step')
fig, ax = plt.subplots()
report2[['num_presymptomatic', 'num_infected', 'num_recovered']].plot(ax=ax)
# Out:
# <AxesSubplot:xlabel='time_step'>

# %%
report2 = pd.read_csv("../reports/model_london_se_commuter_ring/6.csv")
report2 = report2.set_index('time_step')
fig, ax = plt.subplots()
report2[['num_presymptomatic', 'num_infected', 'num_recovered']].plot(ax=ax)
# Out:
# <AxesSubplot:xlabel='time_step'>

# %%
report2 = pd.read_csv("../reports/model_london_se_commuter_ring/7.csv")
report2 = report2.set_index('time_step')
fig, ax = plt.subplots()
report2[['num_presymptomatic', 'num_infected', 'num_recovered']].plot(ax=ax)
# Out:
# <AxesSubplot:xlabel='time_step'>

# %%
report2 = pd.read_csv("../reports/model_london_se_commuter_ring/8.csv")
report2 = report2.set_index('time_step')
fig, ax = plt.subplots()
report2[['num_presymptomatic', 'num_infected', 'num_recovered']].plot(ax=ax)
# Out:
# <AxesSubplot:xlabel='time_step'>

# %%
report2 = pd.read_csv("../reports/model_greater_manchester/8.csv")
report2 = report2.set_index('time_step')
fig, ax = plt.subplots()
report2[['num_presymptomatic', 'num_infected', 'num_recovered']].plot(ax=ax)
# Out:
# <AxesSubplot:xlabel='time_step'>

# %%
report2 = pd.read_csv("../reports/model_greater_manchester/1.csv")
report2 = report2.set_index('time_step')
fig, ax = plt.subplots()
report2.plot(ax=ax)
# Out:
# <AxesSubplot:xlabel='time_step'>
